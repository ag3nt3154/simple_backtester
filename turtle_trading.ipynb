# %%
from utils import misc as misc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



ticker_list = ['UPRO', 'TECL', 'FAS', 'TMF', 'USO', 'DBA', 'GLD', 'DBB', 'EEM', 'BITO']

for ticker in ticker_list:
    print(ticker)
    df = misc.get_price_data(ticker)
    df.to_csv('datasets/daily_price_series/' + ticker + '.csv')
# Out:
# UPRO
# TECL
# FAS
# TMF
# USO
# DBA
# GLD
# DBB
# EEM
# BITO

# %%
port_val = 5000

def update(df):
    # df = misc.clean_df(df)
    df['20_up_bound'] = df['high'].rolling(20).max()
    df['20_low_bound'] = df['low'].rolling(20).min()
    df['10_up_bound'] = df['high'].rolling(10).max()
    df['10_low_bound'] = df['low'].rolling(10).min()

    df['High-Low'] = df['high'] - df['low']
    df['High-PrevClose'] = abs(df['high'] - df['close'].shift(1))
    df['Low-PrevClose'] = abs(df['low'] - df['close'].shift(1))
    df['TR'] = df[['High-Low', 'High-PrevClose', 'Low-PrevClose']].max(axis=1)
    df['ATR'] = df['TR'].rolling(20).mean()
    df = df.dropna()

for ticker in ticker_list:
    print(ticker)
    df = pd.read_csv('datasets/daily_price_series/'+ ticker + '.csv')
    df = misc.clean_df(df)
    update(df)
    # print(f'date:           {str(df["date"].to_list()[-1])[:11]}')
    print(f'last_price:     {df["close"].to_list()[-1]}')
    n = df["ATR"].to_list()[-1]
    print(f'3 x ATR:        {3 * n}')
    print(f'risk unit qty:  {int(port_val * 0.01 / (3 * n))}')
    print('---')
    print(f'long entry:     {df["20_up_bound"].to_list()[-1]}')
    print(f'long exit:      {df["10_low_bound"].to_list()[-1]}')
    print('---')
    print(f'short entry:    {df["20_low_bound"].to_list()[-1]}')
    print(f'short exit:     {df["10_up_bound"].to_list()[-1]}')
    print('----------------------------------------')
# Out:
# UPRO
# date:           2023-06-08
# last_price:     43.06999969482422
# 3 x ATR:        3.6554998397827134
# risk unit qty:  13
# ---
# long entry:     43.27000045776367
# long exit:      38.45000076293945
# ---
# short entry:    37.7400016784668
# short exit:     43.27000045776367
# ----------------------------------------
# TECL
# date:           2023-06-08
# last_price:     46.68999862670898
# 3 x ATR:        6.010500526428218
# risk unit qty:  8
# ---
# long entry:     49.34000015258789
# long exit:      41.0
# ---
# short entry:    35.470001220703125
# short exit:     49.34000015258789
# ----------------------------------------
# FAS
# date:           2023-06-08
# last_price:     60.90999984741211
# 3 x ATR:        6.910500526428225
# risk unit qty:  7
# ---
# long entry:     61.470001220703125
# long exit:      52.47999954223633
# ---
# short entry:    52.47999954223633
# short exit:     61.470001220703125
# ----------------------------------------
# TMF
# date:           2023-06-08
# last_price:     7.739999771118164
# 3 x ATR:        0.7590000629425049
# risk unit qty:  65
# ---
# long entry:     8.600000381469727
# long exit:      7.269999980926514
# ---
# short entry:    7.269999980926514
# short exit:     8.130000114440918
# ----------------------------------------
# USO
# date:           2023-06-08
# last_price:     63.459999084472656
# 3 x ATR:        5.184001922607424
# risk unit qty:  9
# ---
# long entry:     66.23999786376953
# long exit:      60.61000061035156
# ---
# short entry:    60.61000061035156
# short exit:     65.41000366210938
# ----------------------------------------
# DBA
# date:           2023-06-08
# last_price:     21.239999771118164
# 3 x ATR:        0.6555009841918962
# risk unit qty:  76
# ---
# long entry:     21.270000457763672
# long exit:      20.34000015258789
# ---
# short entry:    20.34000015258789
# short exit:     21.270000457763672
# ----------------------------------------
# GLD
# date:           2023-06-08
# last_price:     182.52999877929688
# 3 x ATR:        5.587493133544957
# risk unit qty:  8
# ---
# long entry:     188.80999755859372
# long exit:      180.08999633789062
# ---
# short entry:    180.08999633789062
# short exit:     184.2100067138672
# ----------------------------------------
# DBB
# date:           2023-06-08
# last_price:     18.25
# 3 x ATR:        0.8504997253417964
# risk unit qty:  58
# ---
# long entry:     18.68000030517578
# long exit:      17.399999618530273
# ---
# short entry:    17.399999618530273
# short exit:     18.280000686645508
# ----------------------------------------
# EEM
# date:           2023-06-08
# last_price:     39.68000030517578
# 3 x ATR:        1.4415000915527356
# risk unit qty:  34
# ---
# long entry:     39.93000030517578
# long exit:      37.90999984741211
# ---
# short entry:    37.90999984741211
# short exit:     39.93000030517578
# ----------------------------------------
# BITO
# date:           2023-06-08
# last_price:     14.890000343322754
# 3 x ATR:        1.6285507678985605
# risk unit qty:  30
# ---
# long entry:     16.197999954223633
# long exit:      14.170000076293944
# ---
# short entry:    14.170000076293944
# short exit:     16.197999954223633
# ----------------------------------------
