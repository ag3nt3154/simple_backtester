# %%
from utils import misc as misc
import pandas as pd

spy_constituents = pd.read_csv('datasets/SPY_constituents.csv')


for ticker in spy_constituents['Symbol']:
    print(ticker)
    misc.get_price_data(ticker, location='datasets/daily_price_series/')
# Out:
# MMM
# AOS
# ABT
# ABBV
# ACN
# ATVI
# ADM
# ADBE
# ADP
# AAP
# AES
# AFL
# A
# APD
# AKAM
# ALK
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AMD
# AEE
# AAL
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# ABC
# AME
# AMGN
# APH
# ADI
# ANSS
# AON
# APA
# AAPL
# AMAT
# APTV
# ACGL
# ANET
# AJG
# AIZ
# T
# ATO
# ADSK
# AZO
# AVB
# AVY
# AXON
# BKR
# BALL
# BAC
# BBWI
# BAX
# BDX
# WRB
# BRK-B
# BBY
# BIO
# TECH
# BIIB
# BLK
# BK
# BA
# BKNG
# BWA
# BXP
# BSX
# BMY
# AVGO
# BR
# BRO
# BF-B
# BG
# CHRW
# CDNS
# CZR
# CPT
# CPB
# COF
# CAH
# KMX
# CCL
# CARR
# CTLT
# CAT
# CBOE
# CBRE
# CDW
# CE
# CNC
# CNP
# CDAY
# CF
# CRL
# SCHW
# CHTR
# CVX
# CMG
# CB
# CHD
# CI
# CINF
# CTAS
# CSCO
# C
# CFG
# CLX
# CME
# CMS
# KO
# CTSH
# CL
# CMCSA
# CMA
# CAG
# COP
# ED
# STZ
# CEG
# COO
# CPRT
# GLW
# CTVA
# CSGP
# COST
# CTRA
# CCI
# CSX
# CMI
# CVS
# DHI
# DHR
# DRI
# DVA
# DE
# DAL
# XRAY
# DVN
# DXCM
# FANG
# DLR
# DFS
# DISH
# DIS
# DG
# DLTR
# D
# DPZ
# DOV
# DOW
# DTE
# ...

# %%
for ticker in ['SPY', 'QQQ', 'DIA']:
    misc.get_price_data(ticker, location='datasets/daily_price_series/')
